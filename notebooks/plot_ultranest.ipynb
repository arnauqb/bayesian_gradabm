# %%
import pandas as pd
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 150
#import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import corner
import json
import h5py
import pickle

# %%
true_values = [-0.3, -0.3]

# %%
results = pickle.load(open("../results/ultranest/run5/results.pkl", "rb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 results = pickle.load(open("../results/ultranest/run5/results.pkl", "rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/ultranest/run5/results.pkl'

# %%
plt.plot(results["weighted_samples"]["logl"])

# %%
points = results["weighted_samples"]["points"]
weights = results["weighted_samples"]["weights"]
names = [name.split(".")[-2] for name in results["paramnames"]]

# %%
f = corner.corner(points, labels = names, smooth=2, truths=true_values, weights=weights, show_titles=True, bins=25)
