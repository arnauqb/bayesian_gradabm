# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams["figure.dpi"] = 150

# %%
fname = "../scripts/weight_0.01_second/losses_data.csv"
weight = float(fname.split("/")[2].split("_")[1])
df = pd.read_csv(fname, index_col=0)
df["total_loss"] = df["forecast_train"] + weight * df["reglrise_train"]
#df.plot(logy=True)
print(len(df))
print(f"Best: {np.argmin(df.forecast_train)}")
toplot = df[[col for col in df.columns if "forecast" in col]]
toplot.plot(logy=True)
# Out:
# 134
# Best: 122
# <AxesSubplot: >

# %%
df.plot(logy=True)
# Out:
# <AxesSubplot: >
