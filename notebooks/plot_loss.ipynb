# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 150

# %%
df = pd.read_csv("./losses_data.csv", index_col=0)
df.plot(logy=True)
len(df)
# Out:
# 6

# %%
toplot = df[[col for col in df.columns if "forecast" in col]]
toplot.plot(logy=True)
# Out:
# <AxesSubplot:>
