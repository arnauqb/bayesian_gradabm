# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams["figure.dpi"] = 150

# %%
#fname = "../scripts/weight_0.001_second/losses_data.csv"
fname = "../results/zuko/longer/0.001_longepochs/losses_data.csv"
weight = float(fname.split("/")[4].split("_")[0])

df = pd.read_csv(fname, index_col=0)
df["reglrise_train"] = weight * df['reglrise_train']
df["total_loss"] = df["forecast_train"] + df["reglrise_train"]
#df.plot(logy=True)
print(len(df))
print(f"Best: {np.argmin(df.total_loss)}")
toplot = df[[col for col in df.columns if "forecast" in col]]
df.plot(logy=True)
toplot.plot(logy=True)
# Out:
# 8192
# Best: 3133
# <AxesSubplot: >
