# %% [markdown]
# # BIRDS

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import zuko
import torch
import torch.distributions as distributions
import torch.nn as nn
import pandas as pd
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import warnings

from birds import infer
from birds.models import StochVolSimulator, StochVolPrior
from birds.plotting import plot_posterior

# %%
device = "cpu"

# %% [markdown]
# ## 1. Load simulator model
#
# Here we load the `StochVolSimulator` which we provide as an example of Birds. You can provide your own simulator written in PyTorch as a `torch.nn.Module`.
# The model `forward()` method should take a tensor with the parameters of the model. All other parameters should be specified in the `__init__`.
# The output of the simulator should be a list of tensors, which will be compared to ground truth data. The idea is that we can return multiple time-series.

# %%
model = StochVolSimulator(sigma=0.0, T=100)

# %% [markdown]
# ## 2. Load ground truth data
#
# Here we create some synthetic data as ground truth. It is important that the structure of the ground truth data matches the output of the simulator.

# %%
f, ax = plt.subplots()

true_parameters = torch.log(torch.tensor([15., 20.]))

for i in range(10):
    obs_data = model.forward(true_parameters)
    ax.plot(obs_data[0]);

# %% [markdown]
# ## 3. Specify a prior
#
# We specify a prior. The dimensions of the distribution must be equal to the input parameters.

# %%
prior = StochVolPrior()
#prior = torch.distributions.MultivariateNormal(torch.log(torch.tensor([10, 30.])), 1.0 * torch.eye(2))

# %%
_ = prior.rsample(1000)
plt.hist(torch.exp(_[:, 0]))
# Out:
# (array([ 14., 147., 282., 273., 177.,  69.,  19.,  13.,   4.,   2.]),
#  array([ 1.70348203,  2.57866335,  3.45384479,  4.32902622,  5.20420742,
#          6.07938862,  6.95457029,  7.82975149,  8.70493317,  9.58011436,
#         10.45529556]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 4. Normalizing Flow
#
# We initialize a [zuko](https://github.com/francois-rozet/zuko) flow. See the zuko docs for more info.

# %%
n_params = 2
flow = zuko.flows.NSF(n_params, 1, transforms=5, hidden_features=[50]*3)
# flow = distributions.transformed_distribution.TransformedDistribution(flow, distributions.transforms.ExpTransform())
flow = flow.to(device)

# %% [markdown]
# ## 5. Run inference
#
# We can then call the `infer` function to run inference on the model with the specified flow.
# There are two loss functions available for now: `MSELoss` and `LogMSELoss`. The log version takes the log of the time-series before calculating the mean-square error. This is only suitable for time-series which do not have negatiive values.

# %%
#pdist = nn.PairwiseDistance(p=2.)
y = obs_data[0]
y_matrix = y.reshape(1,-1,1)
y_sigma = torch.median(torch.pow(torch.cdist(y_matrix, y_matrix), 2))
ny = y.shape[0]
kyy = (torch.exp( - torch.pow(torch.cdist(y_matrix, y_matrix), 2) / y_sigma ) - torch.eye(ny)).sum() / (ny * (ny - 1))

def mmd_loss(y, x):
    
    """
    Assumes x, y are shape (T, C)
    """
    nx = x.shape[0]
    x_matrix = x.reshape(1,-1,1)
    kxx = torch.exp( - torch.pow(torch.cdist(x_matrix, x_matrix), 2) / y_sigma )
    #kxx = torch.nan_to_num(kxx, 0.)
    kxx = (kxx - torch.eye(nx)).sum() / (nx * (nx - 1))
    kxy = torch.exp( - torch.pow(torch.cdist(x_matrix, y_matrix), 2) / y_sigma )
    #kxy = torch.nan_to_num(kxy, 0.)
    kxy = kxy.mean()
    if torch.isnan(kxy):
        warnings.warn("kxy nan")
    if torch.isnan(kxx):
        warnings.warn("kxx nan")
    return kxx + kyy - 2 * kxy

# %%
infer(model=model,
    flow = flow,
    prior = prior,
    obs_data = obs_data,
    n_epochs = 1000,
    n_samples_per_epoch = 5,
    n_samples_regularization = 1000,
    w = 0.001,
    save_dir = "./results",
    learning_rate = 1e-3,
    loss = mmd_loss,
    true_values = true_parameters.cpu().numpy(),
    plot_posteriors = "never",
    device=device,
    lims=[(0, 5), (0, 100)],
    clip_val=1.,
    max_num_epochs_without_improvement=1000
)
# Out:
# Training flow with 1960 parameters
#  20%|█████████████████████████████████████████████▋                                                                                                                                                                                         | 198/1000 [00:26<01:47,  7.45it/s, Forecast=0.00593, Reg.=0.0522, total=0.0581]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 infer(model=model,
#       2     flow = flow,
#       3     prior = prior,
#       4     obs_data = obs_data,
#       5     n_epochs = 1000,
#       6     n_samples_per_epoch = 5,
#       7     n_samples_regularization = 1000,
#       8     w = 0.001,
#       9     save_dir = "./results",
#      10     learning_rate = 1e-3,
#      11     loss = mmd_loss,
#      12     true_values = true_parameters.cpu().numpy(),
#      13     plot_posteriors = "never",
#      14     device=device,
#      15     lims=[(0, 5), (0, 100)],
#      16     clip_val=1.,
#      17     max_num_epochs_without_improvement=1000
#      18 )
#
# File ~/code/bayesian_gradabm/birds/infer.py:316, in infer(model, flow, prior, obs_data, diff_mode, jacobian_chunk_size, n_epochs, n_samples_per_epoch, n_samples_regularization, w, clip_val, save_dir, learning_rate, loss, true_values, plot_posteriors, device, preload_model_path, progress_bar, max_num_epochs_without_improvement, **kwargs)
#     307 forecast_loss = forecast_loss_fn(
#     308     model=model,
#     309     flow_cond=flow_cond,
#    (...)
#     313     jacobian_chunk_size=jacobian_chunk_size,
#     314 )
#     315 if mpi_rank == 0:
# --> 316     reglrise_loss = w * _get_regularisation(
#     317         flow_cond=flow_cond, prior=prior, n_samples=n_samples_regularization
#     318     )
#     319     loss = forecast_loss + reglrise_loss
#     320     losses["forecast"].append(forecast_loss.item())
#
# File ~/code/bayesian_gradabm/birds/infer.py:204, in _get_regularisation(flow_cond, prior, n_samples)
#     200 def _get_regularisation(flow_cond, prior, n_samples=5):
#     201     """
#     202     Computes the KL divergence between the flow and the prior
#     203     """
# --> 204     samples = flow_cond.rsample((n_samples,))
#     205     flow_lps = flow_cond.log_prob(samples)
#     206     prior_lps = prior.log_prob(samples)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/zuko/distributions.py:121, in NormalizingFlow.rsample(self, shape)
#     118 else:
#     119     z = self.base.sample(shape)
# --> 121 return self.transform.inv(z)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/distributions/transforms.py:257, in _InverseTransform.__call__(self, x)
#     255 def __call__(self, x):
#     256     assert self._inv is not None
# --> 257     return self._inv._inv_call(x)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/distributions/transforms.py:165, in Transform._inv_call(self, y)
#     161 """
#     162 Inverts the transform `y => x`.
#     163 """
#     164 if self._cache_size == 0:
# --> 165     return self._inverse(y)
#     166 x_old, y_old = self._cached_x_y
#     167 if y is y_old:
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/zuko/transforms.py:112, in ComposedTransform._inverse(self, y)
#     110 def _inverse(self, y: Tensor) -> Tensor:
#     111     for t in reversed(self.transforms):
# --> 112         y = t.inv(y)
#     113     return y
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/distributions/transforms.py:257, in _InverseTransform.__call__(self, x)
#     255 def __call__(self, x):
#     256     assert self._inv is not None
# --> 257     return self._inv._inv_call(x)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/distributions/transforms.py:165, in Transform._inv_call(self, y)
#     161 """
#     162 Inverts the transform `y => x`.
#     163 """
#     164 if self._cache_size == 0:
# --> 165     return self._inverse(y)
#     166 x_old, y_old = self._cached_x_y
#     167 if y is y_old:
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/zuko/transforms.py:697, in AutoregressiveTransform._inverse(self, y)
#     695 x = torch.zeros_like(y)
#     696 for _ in range(self.passes):
# --> 697     x = self.meta(x).inv(y)
#     699 return x
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/zuko/flows.py:310, in MaskedAutoregressiveTransform.meta(self, y, x)
#     306     x = torch.cat(broadcast(x, y, ignore=1), dim=-1)
#     308 total = sum(self.sizes)
# --> 310 phi = self.hyper(x)
#     311 phi = phi.unflatten(-1, (phi.shape[-1] // total, total))
#     312 phi = phi.split(self.sizes, -1)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/modules/activation.py:103, in ReLU.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.relu(input, inplace=self.inplace)
#
# File ~/miniconda3/envs/torch2/lib/python3.10/site-packages/torch/nn/functional.py:1457, in relu(input, inplace)
#    1455     result = torch.relu_(input)
#    1456 else:
# -> 1457     result = torch.relu(input)
#    1458 return result
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6. Plot results

# %% [markdown]
# The results are saved in the specified `save_dir`. In this case, the `results` folder. Each time a parameter configuration beats the best loss, we save the `.pth` object so we can reload the model later. We also save `loss_data.csv` with the loss values:

# %%
df = pd.read_csv("./results/losses_data.csv")
df.plot(logy=True)
# Out:
# <Axes: >

# %% [markdown]
# We can load the best model and plot the posterior doing this:

# %%
best_model = np.sort(glob("./results/saved_models/model_0020.pth"))[-1]
flow.load_state_dict(torch.load(best_model))
# Out:
# <All keys matched successfully>

# %%
flow_cond = flow(torch.zeros(1))
plot_posterior(flow_cond, param_names=["p1", "p2"], true_values=true_parameters.numpy(), lims = None);

# %%
true_parameters
# Out:
# tensor([2.7081, 2.9957])

# %%
f, ax = plt.subplots(figsize=(15, 10))
#ax.plot(obs_data[0], color = "black");

for i in range(10):
    sample = flow(torch.zeros(1)).sample()
    pred = model(sample)
    ax.plot(pred[0], color = "C0", alpha=0.5)
    
for i in range(10):
    sample = prior.rsample(1)
    pred = model(sample[0])
    ax.plot(pred[0], color = "C1", alpha=0.5)
    
for i in range(10):
    obs_data = model.forward(true_parameters)
    ax.plot(obs_data[0], color = "black", alpha=0.5);
    
ax.set_yscale("symlog")
